# %%
import os
import cv2
import dlib
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# Define paths
training_path = '../dataset/train'
testing_path = '../dataset/test'
predictor_path = '../models/shape_predictor_68_face_landmarks.dat'

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(predictor_path)

# %%
def resize_image(image, target_size=(128, 128)):  # VGG uses 224x224 input size
    return cv2.resize(image, target_size, interpolation=cv2.INTER_LINEAR)


def align_face(image, landmarks):
    left_eye = landmarks[36]
    right_eye = landmarks[45]
    dx = right_eye[0] - left_eye[0]
    dy = right_eye[1] - left_eye[1]
    angle = np.degrees(np.arctan2(dy, dx))
    center = (int(np.mean([left_eye[0], right_eye[0]])),
              int(np.mean([left_eye[1], right_eye[1]])))

    rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    return cv2.warpAffine(image, rotation_matrix, (image.shape[1], image.shape[0]))

# %%
# Extract facial landmarks from an image
def extract_landmarks(image_path):
    print(f"Processing image: {image_path}")

    image = cv2.imread(image_path)
    if image is None:
        print(f"Error loading image: {image_path}")
        return None

    image = resize_image(image)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    detections = detector(gray)

    if len(detections) == 0:
        return None

    landmarks = predictor(gray, detections[0])
    landmarks = np.array([[p.x, p.y] for p in landmarks.parts()])
    image = align_face(image, landmarks)

    return image

def augment_image(image):


    return [image]


def extract_images_from_directory(directory):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if not os.path.isdir(label_path):
            continue

        for img_file in os.listdir(label_path):
            img_path = os.path.join(label_path, img_file)
            image = extract_landmarks(img_path)
            if image is None:
                continue

            augmented_images = augment_image(image)
            for aug_image in augmented_images:
                images.append(aug_image)
                labels.append(label)

    return np.array(images), np.array(labels)



X_train, y_train = extract_images_from_directory(training_path)
X_test, y_test = extract_images_from_directory(testing_path)


X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
# X_train = X_train.reshape(X_train.shape[0], 128, 128, 3)  # VGG input shape # Reshaping is done in extract_landmarks
# X_test = X_test.reshape(X_test.shape[0], 128, 128, 3)


label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.transform(y_test)


y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


vgg16_base = VGG16(weights='imagenet', include_top=False, input_shape=(128, 128, 3))


for layer in vgg16_base.layers:
    layer.trainable = False



num_classes = y_train.shape[1]  #one-hot encoded
model = Sequential([
    vgg16_base,
    Flatten(),  # oe else use GlobalAveragePooling2D()
    Dense(512, activation='relu'),
    Dropout(0.48075087656540183),
    Dense(num_classes, activation='softmax')
])
# Out:
# Processing image: ../dataset/train\Heart\Heart(0).jpg
# Processing image: ../dataset/train\Heart\Heart(1).jpg
# Processing image: ../dataset/train\Heart\Heart(10).jpg
# Processing image: ../dataset/train\Heart\Heart(100).jpg
# Processing image: ../dataset/train\Heart\Heart(101).jpg
# Processing image: ../dataset/train\Heart\Heart(102).jpg
# Processing image: ../dataset/train\Heart\Heart(103).jpg
# Processing image: ../dataset/train\Heart\Heart(104).jpg
# Processing image: ../dataset/train\Heart\Heart(105).jpg
# Processing image: ../dataset/train\Heart\Heart(106).jpg
# Processing image: ../dataset/train\Heart\Heart(107).jpg
# Processing image: ../dataset/train\Heart\Heart(108).jpg
# Processing image: ../dataset/train\Heart\Heart(109).jpg
# Processing image: ../dataset/train\Heart\Heart(11).jpg
# Processing image: ../dataset/train\Heart\Heart(110).jpg
# Processing image: ../dataset/train\Heart\Heart(111).jpg
# Processing image: ../dataset/train\Heart\Heart(112).jpg
# Processing image: ../dataset/train\Heart\Heart(113).jpg
# Processing image: ../dataset/train\Heart\Heart(114).jpg
# Processing image: ../dataset/train\Heart\Heart(115).jpg
# Processing image: ../dataset/train\Heart\Heart(116).jpg
# Processing image: ../dataset/train\Heart\Heart(117).jpg
# Processing image: ../dataset/train\Heart\Heart(118).jpg
# Processing image: ../dataset/train\Heart\Heart(119).jpg
# Processing image: ../dataset/train\Heart\Heart(12).jpg
# Processing image: ../dataset/train\Heart\Heart(120).jpg
# Processing image: ../dataset/train\Heart\Heart(121).jpg
# Processing image: ../dataset/train\Heart\Heart(122).jpg
# Processing image: ../dataset/train\Heart\Heart(123).jpg
# Processing image: ../dataset/train\Heart\Heart(124).jpg
# Processing image: ../dataset/train\Heart\Heart(125).jpg
# Processing image: ../dataset/train\Heart\Heart(126).jpg
# Processing image: ../dataset/train\Heart\Heart(127).jpg
# Processing image: ../dataset/train\Heart\Heart(128).jpg
# Processing image: ../dataset/train\Heart\Heart(129).jpg
# Processing image: ../dataset/train\Heart\Heart(13).jpg
# Processing image: ../dataset/train\Heart\Heart(130).jpg
# Processing image: ../dataset/train\Heart\Heart(131).jpg
# Processing image: ../dataset/train\Heart\Heart(132).jpg
# Processing image: ../dataset/train\Heart\Heart(133).jpg
# Processing image: ../dataset/train\Heart\Heart(134).jpg
# Processing image: ../dataset/train\Heart\Heart(135).jpg
# Processing image: ../dataset/train\Heart\Heart(136).jpg
# Processing image: ../dataset/train\Heart\Heart(137).jpg
# Processing image: ../dataset/train\Heart\Heart(138).jpg
# Processing image: ../dataset/train\Heart\Heart(139).jpg
# Processing image: ../dataset/train\Heart\Heart(14).jpg
# Processing image: ../dataset/train\Heart\Heart(140).jpg
# Processing image: ../dataset/train\Heart\Heart(141).jpg
# Processing image: ../dataset/train\Heart\Heart(142).jpg
# Processing image: ../dataset/train\Heart\Heart(143).jpg
# Processing image: ../dataset/train\Heart\Heart(144).jpg
# Processing image: ../dataset/train\Heart\Heart(145).jpg
# Processing image: ../dataset/train\Heart\Heart(146).jpg
# Processing image: ../dataset/train\Heart\Heart(147).jpg
# Processing image: ../dataset/train\Heart\Heart(148).jpg
# Processing image: ../dataset/train\Heart\Heart(149).jpg
# Processing image: ../dataset/train\Heart\Heart(15).jpg
# Processing image: ../dataset/train\Heart\Heart(150).jpg
# Processing image: ../dataset/train\Heart\Heart(151).jpg
# Processing image: ../dataset/train\Heart\Heart(152).jpg
# Processing image: ../dataset/train\Heart\Heart(153).jpg
# Processing image: ../dataset/train\Heart\Heart(154).jpg
# Processing image: ../dataset/train\Heart\Heart(155).jpg
# Processing image: ../dataset/train\Heart\Heart(156).jpg
# Processing image: ../dataset/train\Heart\Heart(157).jpg
# Processing image: ../dataset/train\Heart\Heart(158).jpg
# Processing image: ../dataset/train\Heart\Heart(159).jpg
# Processing image: ../dataset/train\Heart\Heart(16).jpg
# Processing image: ../dataset/train\Heart\Heart(160).jpg
# Processing image: ../dataset/train\Heart\Heart(161).jpg
# Processing image: ../dataset/train\Heart\Heart(162).jpg
# Processing image: ../dataset/train\Heart\Heart(163).jpg
# Processing image: ../dataset/train\Heart\Heart(164).jpg
# Processing image: ../dataset/train\Heart\Heart(165).jpg
# Processing image: ../dataset/train\Heart\Heart(166).jpg
# Processing image: ../dataset/train\Heart\Heart(167).jpg
# Processing image: ../dataset/train\Heart\Heart(168).jpg
# Processing image: ../dataset/train\Heart\Heart(169).jpg
# Processing image: ../dataset/train\Heart\Heart(17).jpg
# Processing image: ../dataset/train\Heart\Heart(170).jpg
# Processing image: ../dataset/train\Heart\Heart(171).jpg
# Processing image: ../dataset/train\Heart\Heart(172).jpg
# Processing image: ../dataset/train\Heart\Heart(173).jpg
# Processing image: ../dataset/train\Heart\Heart(174).jpg
# Processing image: ../dataset/train\Heart\Heart(175).jpg
# Processing image: ../dataset/train\Heart\Heart(176).jpg
# Processing image: ../dataset/train\Heart\Heart(177).jpg
# Processing image: ../dataset/train\Heart\Heart(178).jpg
# Processing image: ../dataset/train\Heart\Heart(179).jpg
# Processing image: ../dataset/train\Heart\Heart(18).jpg
# Processing image: ../dataset/train\Heart\Heart(180).jpg
# Processing image: ../dataset/train\Heart\Heart(181).jpg
# Processing image: ../dataset/train\Heart\Heart(182).jpg
# Processing image: ../dataset/train\Heart\Heart(183).jpg
# Processing image: ../dataset/train\Heart\Heart(184).jpg
# Processing image: ../dataset/train\Heart\Heart(185).jpg
# Processing image: ../dataset/train\Heart\Heart(186).jpg
# Processing image: ../dataset/train\Heart\Heart(187).jpg
# Processing image: ../dataset/train\Heart\Heart(188).jpg
# Processing image: ../dataset/train\Heart\Heart(189).jpg
# Processing image: ../dataset/train\Heart\Heart(19).jpg
# Processing image: ../dataset/train\Heart\Heart(190).jpg
# Processing image: ../dataset/train\Heart\Heart(191).jpg
# Processing image: ../dataset/train\Heart\Heart(192).jpg
# Processing image: ../dataset/train\Heart\Heart(193).jpg
# Processing image: ../dataset/train\Heart\Heart(194).jpg
# Processing image: ../dataset/train\Heart\Heart(195).jpg
# Processing image: ../dataset/train\Heart\Heart(196).jpg
# Processing image: ../dataset/train\Heart\Heart(197).jpg
# Processing image: ../dataset/train\Heart\Heart(198).jpg
# Processing image: ../dataset/train\Heart\Heart(199).jpg
# Processing image: ../dataset/train\Heart\Heart(2).jpg
# Processing image: ../dataset/train\Heart\Heart(20).jpg
# Processing image: ../dataset/train\Heart\Heart(200).jpg
# Processing image: ../dataset/train\Heart\Heart(201).jpg
# Processing image: ../dataset/train\Heart\Heart(202).jpg
# Processing image: ../dataset/train\Heart\Heart(203).jpg
# Processing image: ../dataset/train\Heart\Heart(204).jpg
# Processing image: ../dataset/train\Heart\Heart(205).jpg
# Processing image: ../dataset/train\Heart\Heart(206).jpg
# Processing image: ../dataset/train\Heart\Heart(207).jpg
# Processing image: ../dataset/train\Heart\Heart(208).jpg
# Processing image: ../dataset/train\Heart\Heart(209).jpg
# Processing image: ../dataset/train\Heart\Heart(21).jpg
# Processing image: ../dataset/train\Heart\Heart(210).jpg
# Processing image: ../dataset/train\Heart\Heart(211).jpg
# Processing image: ../dataset/train\Heart\Heart(212).jpg
# Processing image: ../dataset/train\Heart\Heart(213).jpg
# Processing image: ../dataset/train\Heart\Heart(214).jpg
# Processing image: ../dataset/train\Heart\Heart(215).jpg
# Processing image: ../dataset/train\Heart\Heart(216).jpg
# Processing image: ../dataset/train\Heart\Heart(217).jpg
# Processing image: ../dataset/train\Heart\Heart(218).jpg
# Processing image: ../dataset/train\Heart\Heart(219).jpg
# Processing image: ../dataset/train\Heart\Heart(22).jpg
# Processing image: ../dataset/train\Heart\Heart(220).jpg
# Processing image: ../dataset/train\Heart\Heart(221).jpg
# Processing image: ../dataset/train\Heart\Heart(222).jpg
# Processing image: ../dataset/train\Heart\Heart(223).jpg
# Processing image: ../dataset/train\Heart\Heart(224).jpg
# Processing image: ../dataset/train\Heart\Heart(225).jpg
# Processing image: ../dataset/train\Heart\Heart(226).jpg
# Processing image: ../dataset/train\Heart\Heart(227).jpg
# Processing image: ../dataset/train\Heart\Heart(228).jpg
# Processing image: ../dataset/train\Heart\Heart(229).jpg
# Processing image: ../dataset/train\Heart\Heart(23).jpg
# Processing image: ../dataset/train\Heart\Heart(230).jpg
# Processing image: ../dataset/train\Heart\Heart(231).jpg
# Processing image: ../dataset/train\Heart\Heart(232).jpg
# Processing image: ../dataset/train\Heart\Heart(233).jpg
# Processing image: ../dataset/train\Heart\Heart(234).jpg
# Processing image: ../dataset/train\Heart\Heart(235).jpg
# Processing image: ../dataset/train\Heart\Heart(236).jpg
# Processing image: ../dataset/train\Heart\Heart(237).jpg
# Processing image: ../dataset/train\Heart\Heart(238).jpg
# Processing image: ../dataset/train\Heart\Heart(239).jpg
# Processing image: ../dataset/train\Heart\Heart(24).jpg
# Processing image: ../dataset/train\Heart\Heart(240).jpg
# Processing image: ../dataset/train\Heart\Heart(241).jpg
# Processing image: ../dataset/train\Heart\Heart(242).jpg
# Processing image: ../dataset/train\Heart\Heart(243).jpg
# Processing image: ../dataset/train\Heart\Heart(244).jpg
# Processing image: ../dataset/train\Heart\Heart(245).jpg
# Processing image: ../dataset/train\Heart\Heart(246).jpg
# Processing image: ../dataset/train\Heart\Heart(247).jpg
# Processing image: ../dataset/train\Heart\Heart(248).jpg
# Processing image: ../dataset/train\Heart\Heart(249).jpg
# Processing image: ../dataset/train\Heart\Heart(25).jpg
# Processing image: ../dataset/train\Heart\Heart(250).jpg
# Processing image: ../dataset/train\Heart\Heart(251).jpg
# Processing image: ../dataset/train\Heart\Heart(252).jpg
# Processing image: ../dataset/train\Heart\Heart(253).jpg
# Processing image: ../dataset/train\Heart\Heart(254).jpg
# Processing image: ../dataset/train\Heart\Heart(255).jpg
# Processing image: ../dataset/train\Heart\Heart(256).jpg
# Processing image: ../dataset/train\Heart\Heart(257).jpg
# Processing image: ../dataset/train\Heart\Heart(258).jpg
# Processing image: ../dataset/train\Heart\Heart(259).jpg
# Processing image: ../dataset/train\Heart\Heart(26).jpg
# Processing image: ../dataset/train\Heart\Heart(260).jpg
# Processing image: ../dataset/train\Heart\Heart(261).jpg
# Processing image: ../dataset/train\Heart\Heart(262).jpg
# Processing image: ../dataset/train\Heart\Heart(263).jpg
# Processing image: ../dataset/train\Heart\Heart(264).jpg
# Processing image: ../dataset/train\Heart\Heart(265).jpg
# Processing image: ../dataset/train\Heart\Heart(266).jpg
# Processing image: ../dataset/train\Heart\Heart(267).jpg
# Processing image: ../dataset/train\Heart\Heart(268).jpg
# Processing image: ../dataset/train\Heart\Heart(269).jpg
# Processing image: ../dataset/train\Heart\Heart(27).jpg
# Processing image: ../dataset/train\Heart\Heart(270).jpg
# Processing image: ../dataset/train\Heart\Heart(271).jpg
# Processing image: ../dataset/train\Heart\Heart(272).jpg
# Processing image: ../dataset/train\Heart\Heart(273).jpg
# Processing image: ../dataset/train\Heart\Heart(274).jpg
# Processing image: ../dataset/train\Heart\Heart(275).jpg
# Processing image: ../dataset/train\Heart\Heart(276).jpg
# Processing image: ../dataset/train\Heart\Heart(277).jpg
# Processing image: ../dataset/train\Heart\Heart(278).jpg
# Processing image: ../dataset/train\Heart\Heart(279).jpg
# Processing image: ../dataset/train\Heart\Heart(28).jpg
# Processing image: ../dataset/train\Heart\Heart(280).jpg
# Processing image: ../dataset/train\Heart\Heart(281).jpg
# Processing image: ../dataset/train\Heart\Heart(282).jpg
# Processing image: ../dataset/train\Heart\Heart(283).jpg
# Processing image: ../dataset/train\Heart\Heart(284).jpg
# Processing image: ../dataset/train\Heart\Heart(285).jpg
# Processing image: ../dataset/train\Heart\Heart(286).jpg
# Processing image: ../dataset/train\Heart\Heart(287).jpg
# Processing image: ../dataset/train\Heart\Heart(288).jpg
# Processing image: ../dataset/train\Heart\Heart(289).jpg
# Processing image: ../dataset/train\Heart\Heart(29).jpg
# Processing image: ../dataset/train\Heart\Heart(290).jpg
# Processing image: ../dataset/train\Heart\Heart(291).jpg
# Processing image: ../dataset/train\Heart\Heart(292).jpg
# Processing image: ../dataset/train\Heart\Heart(293).jpg
# Processing image: ../dataset/train\Heart\Heart(294).jpg
# Processing image: ../dataset/train\Heart\Heart(295).jpg
# Processing image: ../dataset/train\Heart\Heart(296).jpg
# Processing image: ../dataset/train\Heart\Heart(297).jpg
# Processing image: ../dataset/train\Heart\Heart(298).jpg
# Processing image: ../dataset/train\Heart\Heart(299).jpg
# Processing image: ../dataset/train\Heart\Heart(3).jpg
# Processing image: ../dataset/train\Heart\Heart(30).jpg
# Processing image: ../dataset/train\Heart\Heart(300).jpg
# Processing image: ../dataset/train\Heart\Heart(301).jpg
# Processing image: ../dataset/train\Heart\Heart(302).jpg
# Processing image: ../dataset/train\Heart\Heart(303).jpg
# Processing image: ../dataset/train\Heart\Heart(304).jpg
# Processing image: ../dataset/train\Heart\Heart(305).jpg
# Processing image: ../dataset/train\Heart\Heart(306).jpg
# Processing image: ../dataset/train\Heart\Heart(307).jpg
# Processing image: ../dataset/train\Heart\Heart(308).jpg
# Processing image: ../dataset/train\Heart\Heart(309).jpg
# Processing image: ../dataset/train\Heart\Heart(31).jpg
# Processing image: ../dataset/train\Heart\Heart(310).jpg
# Processing image: ../dataset/train\Heart\Heart(311).jpg
# Processing image: ../dataset/train\Heart\Heart(312).jpg
# Processing image: ../dataset/train\Heart\Heart(313).jpg
# Processing image: ../dataset/train\Heart\Heart(314).jpg
# Processing image: ../dataset/train\Heart\Heart(315).jpg
# Processing image: ../dataset/train\Heart\Heart(316).jpg
# Processing image: ../dataset/train\Heart\Heart(317).jpg
# Processing image: ../dataset/train\Heart\Heart(318).jpg
# Processing image: ../dataset/train\Heart\Heart(319).jpg
# Processing image: ../dataset/train\Heart\Heart(32).jpg
# Processing image: ../dataset/train\Heart\Heart(320).jpg
# Processing image: ../dataset/train\Heart\Heart(321).jpg
# Processing image: ../dataset/train\Heart\Heart(322).jpg
# Processing image: ../dataset/train\Heart\Heart(323).jpg
# Processing image: ../dataset/train\Heart\Heart(324).jpg
# Processing image: ../dataset/train\Heart\Heart(325).jpg
# Processing image: ../dataset/train\Heart\Heart(326).jpg
# Processing image: ../dataset/train\Heart\Heart(327).jpg
# Processing image: ../dataset/train\Heart\Heart(328).jpg
# Processing image: ../dataset/train\Heart\Heart(329).jpg
# Processing image: ../dataset/train\Heart\Heart(33).jpg
# Processing image: ../dataset/train\Heart\Heart(330).jpg
# Processing image: ../dataset/train\Heart\Heart(331).jpg
# Processing image: ../dataset/train\Heart\Heart(332).jpg
# Processing image: ../dataset/train\Heart\Heart(333).jpg
# Processing image: ../dataset/train\Heart\Heart(334).jpg
# Processing image: ../dataset/train\Heart\Heart(335).jpg
# Processing image: ../dataset/train\Heart\Heart(336).jpg
# Processing image: ../dataset/train\Heart\Heart(337).jpg
# Processing image: ../dataset/train\Heart\Heart(338).jpg
# Processing image: ../dataset/train\Heart\Heart(339).jpg
# Processing image: ../dataset/train\Heart\Heart(34).jpg
# Processing image: ../dataset/train\Heart\Heart(340).jpg
# Processing image: ../dataset/train\Heart\Heart(341).jpg
# Processing image: ../dataset/train\Heart\Heart(342).jpg
# Processing image: ../dataset/train\Heart\Heart(343).jpg
# Processing image: ../dataset/train\Heart\Heart(344).jpg
# Processing image: ../dataset/train\Heart\Heart(345).jpg
# Processing image: ../dataset/train\Heart\Heart(346).jpg
# Processing image: ../dataset/train\Heart\Heart(347).jpg
# Processing image: ../dataset/train\Heart\Heart(348).jpg
# Processing image: ../dataset/train\Heart\Heart(349).jpg
# Processing image: ../dataset/train\Heart\Heart(35).jpg
# Processing image: ../dataset/train\Heart\Heart(350).jpg
# Processing image: ../dataset/train\Heart\Heart(351).jpg
# Processing image: ../dataset/train\Heart\Heart(352).jpg
# Processing image: ../dataset/train\Heart\Heart(353).jpg
# Processing image: ../dataset/train\Heart\Heart(354).jpg
# Processing image: ../dataset/train\Heart\Heart(355).jpg
# Processing image: ../dataset/train\Heart\Heart(356).jpg
# Processing image: ../dataset/train\Heart\Heart(357).jpg
# Processing image: ../dataset/train\Heart\Heart(358).jpg
# Processing image: ../dataset/train\Heart\Heart(359).jpg
# Processing image: ../dataset/train\Heart\Heart(36).jpg
# Processing image: ../dataset/train\Heart\Heart(360).jpg
# Processing image: ../dataset/train\Heart\Heart(361).jpg
# Processing image: ../dataset/train\Heart\Heart(362).jpg
# Processing image: ../dataset/train\Heart\Heart(363).jpg
# Processing image: ../dataset/train\Heart\Heart(364).jpg
# Processing image: ../dataset/train\Heart\Heart(365).jpg
# Processing image: ../dataset/train\Heart\Heart(366).jpg
# Processing image: ../dataset/train\Heart\Heart(367).jpg
# Processing image: ../dataset/train\Heart\Heart(368).jpg
# Processing image: ../dataset/train\Heart\Heart(369).jpg
# Processing image: ../dataset/train\Heart\Heart(37).jpg
# Processing image: ../dataset/train\Heart\Heart(370).jpg
# Processing image: ../dataset/train\Heart\Heart(371).jpg
# Processing image: ../dataset/train\Heart\Heart(372).jpg
# Processing image: ../dataset/train\Heart\Heart(373).jpg
# Processing image: ../dataset/train\Heart\Heart(374).jpg
# Processing image: ../dataset/train\Heart\Heart(375).jpg
# Processing image: ../dataset/train\Heart\Heart(376).jpg
# Processing image: ../dataset/train\Heart\Heart(377).jpg
# Processing image: ../dataset/train\Heart\Heart(378).jpg
# Processing image: ../dataset/train\Heart\Heart(379).jpg
# Processing image: ../dataset/train\Heart\Heart(38).jpg
# Processing image: ../dataset/train\Heart\Heart(380).jpg
# Processing image: ../dataset/train\Heart\Heart(381).jpg
# Processing image: ../dataset/train\Heart\Heart(382).jpg
# Processing image: ../dataset/train\Heart\Heart(383).jpg
# Processing image: ../dataset/train\Heart\Heart(384).jpg
# Processing image: ../dataset/train\Heart\Heart(385).jpg
# Processing image: ../dataset/train\Heart\Heart(386).jpg
# Processing image: ../dataset/train\Heart\Heart(387).jpg
# Processing image: ../dataset/train\Heart\Heart(388).jpg
# Processing image: ../dataset/train\Heart\Heart(389).jpg
# Processing image: ../dataset/train\Heart\Heart(39).jpg
# Processing image: ../dataset/train\Heart\Heart(390).jpg
# Processing image: ../dataset/train\Heart\Heart(391).jpg
# Processing image: ../dataset/train\Heart\Heart(392).jpg
# Processing image: ../dataset/train\Heart\Heart(393).jpg
# Processing image: ../dataset/train\Heart\Heart(394).jpg
# Processing image: ../dataset/train\Heart\Heart(395).jpg
# Processing image: ../dataset/train\Heart\Heart(396).jpg
# Processing image: ../dataset/train\Heart\Heart(397).jpg
# Processing image: ../dataset/train\Heart\Heart(398).jpg
# Processing image: ../dataset/train\Heart\Heart(399).jpg
# Processing image: ../dataset/train\Heart\Heart(4).jpg
# Processing image: ../dataset/train\Heart\Heart(40).jpg
# Processing image: ../dataset/train\Heart\Heart(400).jpg
# Processing image: ../dataset/train\Heart\Heart(401).jpg
# Processing image: ../dataset/train\Heart\Heart(402).jpg
# Processing image: ../dataset/train\Heart\Heart(403).jpg
# Processing image: ../dataset/train\Heart\Heart(404).jpg
# Processing image: ../dataset/train\Heart\Heart(405).jpg
# Processing image: ../dataset/train\Heart\Heart(406).jpg
# Processing image: ../dataset/train\Heart\Heart(407).jpg
# Processing image: ../dataset/train\Heart\Heart(408).jpg
# Processing image: ../dataset/train\Heart\Heart(409).jpg
# Processing image: ../dataset/train\Heart\Heart(41).jpg
# Processing image: ../dataset/train\Heart\Heart(410).jpg
# Processing image: ../dataset/train\Heart\Heart(411).jpg
# Processing image: ../dataset/train\Heart\Heart(412).jpg
# Processing image: ../dataset/train\Heart\Heart(413).jpg
# Processing image: ../dataset/train\Heart\Heart(414).jpg
# Processing image: ../dataset/train\Heart\Heart(415).jpg
# Processing image: ../dataset/train\Heart\Heart(416).jpg
# Processing image: ../dataset/train\Heart\Heart(417).jpg
# Processing image: ../dataset/train\Heart\Heart(418).jpg
# Processing image: ../dataset/train\Heart\Heart(419).jpg
# Processing image: ../dataset/train\Heart\Heart(42).jpg
# Processing image: ../dataset/train\Heart\Heart(420).jpg
# Processing image: ../dataset/train\Heart\Heart(421).jpg
# Processing image: ../dataset/train\Heart\Heart(422).jpg
# Processing image: ../dataset/train\Heart\Heart(423).jpg
# Processing image: ../dataset/train\Heart\Heart(424).jpg
# Processing image: ../dataset/train\Heart\Heart(425).jpg
# Processing image: ../dataset/train\Heart\Heart(426).jpg
# Processing image: ../dataset/train\Heart\Heart(427).jpg
# Processing image: ../dataset/train\Heart\Heart(428).jpg
# Processing image: ../dataset/train\Heart\Heart(429).jpg
# Processing image: ../dataset/train\Heart\Heart(43).jpg
# Processing image: ../dataset/train\Heart\Heart(430).jpg
# Processing image: ../dataset/train\Heart\Heart(431).jpg
# Processing image: ../dataset/train\Heart\Heart(432).jpg
# Processing image: ../dataset/train\Heart\Heart(433).jpg
# Processing image: ../dataset/train\Heart\Heart(434).jpg
# Processing image: ../dataset/train\Heart\Heart(435).jpg
# Processing image: ../dataset/train\Heart\Heart(436).jpg
# Processing image: ../dataset/train\Heart\Heart(437).jpg
# Processing image: ../dataset/train\Heart\Heart(438).jpg
# Processing image: ../dataset/train\Heart\Heart(439).jpg
# Processing image: ../dataset/train\Heart\Heart(44).jpg
# Processing image: ../dataset/train\Heart\Heart(440).jpg
# Processing image: ../dataset/train\Heart\Heart(441).jpg
# Processing image: ../dataset/train\Heart\Heart(442).jpg
# Processing image: ../dataset/train\Heart\Heart(443).jpg
# Processing image: ../dataset/train\Heart\Heart(444).jpg
# Processing image: ../dataset/train\Heart\Heart(445).jpg
# Processing image: ../dataset/train\Heart\Heart(446).jpg
# Processing image: ../dataset/train\Heart\Heart(447).jpg
# Processing image: ../dataset/train\Heart\Heart(448).jpg
# Processing image: ../dataset/train\Heart\Heart(449).jpg
# Processing image: ../dataset/train\Heart\Heart(45).jpg
# Processing image: ../dataset/train\Heart\Heart(450).jpg
# Processing image: ../dataset/train\Heart\Heart(451).jpg
# Processing image: ../dataset/train\Heart\Heart(452).jpg
# Processing image: ../dataset/train\Heart\Heart(453).jpg
# Processing image: ../dataset/train\Heart\Heart(454).jpg
# Processing image: ../dataset/train\Heart\Heart(455).jpg
# Processing image: ../dataset/train\Heart\Heart(456).jpg
# Processing image: ../dataset/train\Heart\Heart(457).jpg
# Processing image: ../dataset/train\Heart\Heart(458).jpg
# Processing image: ../dataset/train\Heart\Heart(459).jpg
# Processing image: ../dataset/train\Heart\Heart(46).jpg
# Processing image: ../dataset/train\Heart\Heart(460).jpg
# Processing image: ../dataset/train\Heart\Heart(461).jpg
# Processing image: ../dataset/train\Heart\Heart(462).jpg
# Processing image: ../dataset/train\Heart\Heart(463).jpg
# Processing image: ../dataset/train\Heart\Heart(464).jpg
# Processing image: ../dataset/train\Heart\Heart(465).jpg
# Processing image: ../dataset/train\Heart\Heart(466).jpg
# Processing image: ../dataset/train\Heart\Heart(467).jpg
# Processing image: ../dataset/train\Heart\Heart(468).jpg
# Processing image: ../dataset/train\Heart\Heart(469).jpg
# Processing image: ../dataset/train\Heart\Heart(47).jpg
# Processing image: ../dataset/train\Heart\Heart(470).jpg
# Processing image: ../dataset/train\Heart\Heart(471).jpg
# Processing image: ../dataset/train\Heart\Heart(472).jpg
# Processing image: ../dataset/train\Heart\Heart(473).jpg
# Processing image: ../dataset/train\Heart\Heart(474).jpg
# Processing image: ../dataset/train\Heart\Heart(475).jpg
# Processing image: ../dataset/train\Heart\Heart(476).jpg
# Processing image: ../dataset/train\Heart\Heart(477).jpg
# Processing image: ../dataset/train\Heart\Heart(478).jpg
# Processing image: ../dataset/train\Heart\Heart(479).jpg
# Processing image: ../dataset/train\Heart\Heart(48).jpg
# Processing image: ../dataset/train\Heart\Heart(480).jpg
# Processing image: ../dataset/train\Heart\Heart(481).jpg
# Processing image: ../dataset/train\Heart\Heart(482).jpg
# Processing image: ../dataset/train\Heart\Heart(483).jpg
# Processing image: ../dataset/train\Heart\Heart(484).jpg
# Processing image: ../dataset/train\Heart\Heart(485).jpg
# Processing image: ../dataset/train\Heart\Heart(486).jpg
# Processing image: ../dataset/train\Heart\Heart(487).jpg
# Processing image: ../dataset/train\Heart\Heart(488).jpg
# Processing image: ../dataset/train\Heart\Heart(489).jpg
# Processing image: ../dataset/train\Heart\Heart(49).jpg
# Processing image: ../dataset/train\Heart\Heart(490).jpg
# Processing image: ../dataset/train\Heart\Heart(491).jpg
# Processing image: ../dataset/train\Heart\Heart(492).jpg
# Processing image: ../dataset/train\Heart\Heart(493).jpg
# Processing image: ../dataset/train\Heart\Heart(494).jpg
# Processing image: ../dataset/train\Heart\Heart(495).jpg
# Processing image: ../dataset/train\Heart\Heart(496).jpg
# Processing image: ../dataset/train\Heart\Heart(497).jpg
# Processing image: ../dataset/train\Heart\Heart(498).jpg
# Processing image: ../dataset/train\Heart\Heart(499).jpg
# Processing image: ../dataset/train\Heart\Heart(5).jpg
# Processing image: ../dataset/train\Heart\Heart(50).jpg
# Processing image: ../dataset/train\Heart\Heart(500).jpg
# Processing image: ../dataset/train\Heart\Heart(501).jpg
# Processing image: ../dataset/train\Heart\Heart(502).jpg
# Processing image: ../dataset/train\Heart\Heart(503).jpg
# Processing image: ../dataset/train\Heart\Heart(504).jpg
# Processing image: ../dataset/train\Heart\Heart(505).jpg
# Processing image: ../dataset/train\Heart\Heart(506).jpg
# Processing image: ../dataset/train\Heart\Heart(507).jpg
# Processing image: ../dataset/train\Heart\Heart(508).jpg
# Processing image: ../dataset/train\Heart\Heart(509).jpg
# Processing image: ../dataset/train\Heart\Heart(51).jpg
# Processing image: ../dataset/train\Heart\Heart(510).jpg
# Processing image: ../dataset/train\Heart\Heart(511).jpg
# Processing image: ../dataset/train\Heart\Heart(512).jpg
# Processing image: ../dataset/train\Heart\Heart(513).jpg
# Processing image: ../dataset/train\Heart\Heart(514).jpg
# Processing image: ../dataset/train\Heart\Heart(515).jpg
# Processing image: ../dataset/train\Heart\Heart(516).jpg
# Processing image: ../dataset/train\Heart\Heart(517).jpg
# Processing image: ../dataset/train\Heart\Heart(518).jpg
# Processing image: ../dataset/train\Heart\Heart(519).jpg
# Processing image: ../dataset/train\Heart\Heart(52).jpg
# Processing image: ../dataset/train\Heart\Heart(520).jpg
# Processing image: ../dataset/train\Heart\Heart(521).jpg
# Processing image: ../dataset/train\Heart\Heart(522).jpg
# Processing image: ../dataset/train\Heart\Heart(523).jpg
# Processing image: ../dataset/train\Heart\Heart(524).jpg
# Processing image: ../dataset/train\Heart\Heart(525).jpg
# Processing image: ../dataset/train\Heart\Heart(526).jpg
# Processing image: ../dataset/train\Heart\Heart(527).jpg
# Processing image: ../dataset/train\Heart\Heart(528).jpg
# Processing image: ../dataset/train\Heart\Heart(529).jpg
# Processing image: ../dataset/train\Heart\Heart(53).jpg
# Processing image: ../dataset/train\Heart\Heart(530).jpg
# Processing image: ../dataset/train\Heart\Heart(531).jpg
# Processing image: ../dataset/train\Heart\Heart(532).jpg
# Processing image: ../dataset/train\Heart\Heart(533).jpg
# Processing image: ../dataset/train\Heart\Heart(534).jpg
# Processing image: ../dataset/train\Heart\Heart(535).jpg
# Processing image: ../dataset/train\Heart\Heart(536).jpg
# Processing image: ../dataset/train\Heart\Heart(537).jpg
# Processing image: ../dataset/train\Heart\Heart(538).jpg
# Processing image: ../dataset/train\Heart\Heart(539).jpg
# Processing image: ../dataset/train\Heart\Heart(54).jpg
# Processing image: ../dataset/train\Heart\Heart(540).jpg
# Processing image: ../dataset/train\Heart\Heart(541).jpg
# Processing image: ../dataset/train\Heart\Heart(542).jpg
# Processing image: ../dataset/train\Heart\Heart(543).jpg
# Processing image: ../dataset/train\Heart\Heart(544).jpg
# Processing image: ../dataset/train\Heart\Heart(545).jpg
# Processing image: ../dataset/train\Heart\Heart(546).jpg
# Processing image: ../dataset/train\Heart\Heart(547).jpg
# Processing image: ../dataset/train\Heart\Heart(548).jpg
# Processing image: ../dataset/train\Heart\Heart(549).jpg
# Processing image: ../dataset/train\Heart\Heart(55).jpg
# Processing image: ../dataset/train\Heart\Heart(550).jpg
# Processing image: ../dataset/train\Heart\Heart(551).jpg
# Processing image: ../dataset/train\Heart\Heart(552).jpg
# Processing image: ../dataset/train\Heart\Heart(553).jpg
# Processing image: ../dataset/train\Heart\Heart(554).jpg
# Processing image: ../dataset/train\Heart\Heart(555).jpg
# Processing image: ../dataset/train\Heart\Heart(556).jpg
# Processing image: ../dataset/train\Heart\Heart(557).jpg
# Processing image: ../dataset/train\Heart\Heart(558).jpg
# Processing image: ../dataset/train\Heart\Heart(559).jpg
# Processing image: ../dataset/train\Heart\Heart(56).jpg
# Processing image: ../dataset/train\Heart\Heart(560).jpg
# Processing image: ../dataset/train\Heart\Heart(561).jpg
# Processing image: ../dataset/train\Heart\Heart(562).jpg
# Processing image: ../dataset/train\Heart\Heart(563).jpg
# Processing image: ../dataset/train\Heart\Heart(564).jpg
# Processing image: ../dataset/train\Heart\Heart(565).jpg
# Processing image: ../dataset/train\Heart\Heart(566).jpg
# Processing image: ../dataset/train\Heart\Heart(567).jpg
# Processing image: ../dataset/train\Heart\Heart(568).jpg
# Processing image: ../dataset/train\Heart\Heart(569).jpg
# Processing image: ../dataset/train\Heart\Heart(57).jpg
# Processing image: ../dataset/train\Heart\Heart(570).jpg
# Processing image: ../dataset/train\Heart\Heart(571).jpg
# Processing image: ../dataset/train\Heart\Heart(572).jpg
# Processing image: ../dataset/train\Heart\Heart(573).jpg
# Processing image: ../dataset/train\Heart\Heart(574).jpg
# Processing image: ../dataset/train\Heart\Heart(575).jpg
# Processing image: ../dataset/train\Heart\Heart(576).jpg
# Processing image: ../dataset/train\Heart\Heart(577).jpg
# Processing image: ../dataset/train\Heart\Heart(578).jpg
# Processing image: ../dataset/train\Heart\Heart(579).jpg
# Processing image: ../dataset/train\Heart\Heart(58).jpg
# Processing image: ../dataset/train\Heart\Heart(580).jpg
# Processing image: ../dataset/train\Heart\Heart(581).jpg
# Processing image: ../dataset/train\Heart\Heart(582).jpg
# Processing image: ../dataset/train\Heart\Heart(583).jpg
# Processing image: ../dataset/train\Heart\Heart(584).jpg
# Processing image: ../dataset/train\Heart\Heart(585).jpg
# Processing image: ../dataset/train\Heart\Heart(586).jpg
# Processing image: ../dataset/train\Heart\Heart(587).jpg
# Processing image: ../dataset/train\Heart\Heart(588).jpg
# Processing image: ../dataset/train\Heart\Heart(589).jpg
# Processing image: ../dataset/train\Heart\Heart(59).jpg
# Processing image: ../dataset/train\Heart\Heart(590).jpg
# Processing image: ../dataset/train\Heart\Heart(591).jpg
# Processing image: ../dataset/train\Heart\Heart(592).jpg
# Processing image: ../dataset/train\Heart\Heart(593).jpg
# Processing image: ../dataset/train\Heart\Heart(594).jpg
# Processing image: ../dataset/train\Heart\Heart(595).jpg
# Processing image: ../dataset/train\Heart\Heart(596).jpg
# Processing image: ../dataset/train\Heart\Heart(597).jpg
# Processing image: ../dataset/train\Heart\Heart(598).jpg
# Processing image: ../dataset/train\Heart\Heart(599).jpg
# Processing image: ../dataset/train\Heart\Heart(6).jpg
# Processing image: ../dataset/train\Heart\Heart(60).jpg
# Processing image: ../dataset/train\Heart\Heart(600).jpg
# Processing image: ../dataset/train\Heart\Heart(601).jpg
# Processing image: ../dataset/train\Heart\Heart(602).jpg
# Processing image: ../dataset/train\Heart\Heart(603).jpg
# Processing image: ../dataset/train\Heart\Heart(604).jpg
# Processing image: ../dataset/train\Heart\Heart(605).jpg
# Processing image: ../dataset/train\Heart\Heart(606).jpg
# Processing image: ../dataset/train\Heart\Heart(607).jpg
# Processing image: ../dataset/train\Heart\Heart(608).jpg
# Processing image: ../dataset/train\Heart\Heart(609).jpg
# Processing image: ../dataset/train\Heart\Heart(61).jpg
# Processing image: ../dataset/train\Heart\Heart(610).jpg
# Processing image: ../dataset/train\Heart\Heart(611).jpg
# Processing image: ../dataset/train\Heart\Heart(612).jpg
# Processing image: ../dataset/train\Heart\Heart(613).jpg
# Processing image: ../dataset/train\Heart\Heart(614).jpg
# Processing image: ../dataset/train\Heart\Heart(615).jpg
# Processing image: ../dataset/train\Heart\Heart(616).jpg
# Processing image: ../dataset/train\Heart\Heart(617).jpg
# Processing image: ../dataset/train\Heart\Heart(618).jpg
# Processing image: ../dataset/train\Heart\Heart(619).jpg
# Processing image: ../dataset/train\Heart\Heart(62).jpg
# Processing image: ../dataset/train\Heart\Heart(620).jpg
# Processing image: ../dataset/train\Heart\Heart(621).jpg
# Processing image: ../dataset/train\Heart\Heart(622).jpg
# Processing image: ../dataset/train\Heart\Heart(623).jpg
# Processing image: ../dataset/train\Heart\Heart(624).jpg
# Processing image: ../dataset/train\Heart\Heart(625).jpg
# Processing image: ../dataset/train\Heart\Heart(626).jpg
# Processing image: ../dataset/train\Heart\Heart(627).jpg
# Processing image: ../dataset/train\Heart\Heart(628).jpg
# Processing image: ../dataset/train\Heart\Heart(629).jpg
# Processing image: ../dataset/train\Heart\Heart(63).jpg
# Processing image: ../dataset/train\Heart\Heart(630).jpg
# Processing image: ../dataset/train\Heart\Heart(631).jpg
# Processing image: ../dataset/train\Heart\Heart(632).jpg
# Processing image: ../dataset/train\Heart\Heart(633).jpg
# Processing image: ../dataset/train\Heart\Heart(634).jpg
# Processing image: ../dataset/train\Heart\Heart(635).jpg
# Processing image: ../dataset/train\Heart\Heart(636).jpg
# Processing image: ../dataset/train\Heart\Heart(637).jpg
# Processing image: ../dataset/train\Heart\Heart(638).jpg
# Processing image: ../dataset/train\Heart\Heart(639).jpg
# Processing image: ../dataset/train\Heart\Heart(64).jpg
# Processing image: ../dataset/train\Heart\Heart(640).jpg
# Processing image: ../dataset/train\Heart\Heart(641).jpg
# Processing image: ../dataset/train\Heart\Heart(642).jpg
# Processing image: ../dataset/train\Heart\Heart(643).jpg
# Processing image: ../dataset/train\Heart\Heart(644).jpg
# Processing image: ../dataset/train\Heart\Heart(645).jpg
# Processing image: ../dataset/train\Heart\Heart(646).jpg
# Processing image: ../dataset/train\Heart\Heart(647).jpg
# Processing image: ../dataset/train\Heart\Heart(648).jpg
# Processing image: ../dataset/train\Heart\Heart(649).jpg
# Processing image: ../dataset/train\Heart\Heart(65).jpg
# Processing image: ../dataset/train\Heart\Heart(650).jpg
# Processing image: ../dataset/train\Heart\Heart(651).jpg
# Processing image: ../dataset/train\Heart\Heart(652).jpg
# Processing image: ../dataset/train\Heart\Heart(653).jpg
# Processing image: ../dataset/train\Heart\Heart(654).jpg
# Processing image: ../dataset/train\Heart\Heart(655).jpg
# Processing image: ../dataset/train\Heart\Heart(656).jpg
# Processing image: ../dataset/train\Heart\Heart(657).jpg
# Processing image: ../dataset/train\Heart\Heart(658).jpg
# Processing image: ../dataset/train\Heart\Heart(659).jpg
# Processing image: ../dataset/train\Heart\Heart(66).jpg
# Processing image: ../dataset/train\Heart\Heart(660).jpg
# Processing image: ../dataset/train\Heart\Heart(661).jpg
# Processing image: ../dataset/train\Heart\Heart(662).jpg
# Processing image: ../dataset/train\Heart\Heart(663).jpg
# Processing image: ../dataset/train\Heart\Heart(664).jpg
# Processing image: ../dataset/train\Heart\Heart(665).jpg
# Processing image: ../dataset/train\Heart\Heart(666).jpg
# Processing image: ../dataset/train\Heart\Heart(667).jpg
# Processing image: ../dataset/train\Heart\Heart(668).jpg
# Processing image: ../dataset/train\Heart\Heart(669).jpg
# Processing image: ../dataset/train\Heart\Heart(67).jpg
# Processing image: ../dataset/train\Heart\Heart(670).jpg
# Processing image: ../dataset/train\Heart\Heart(671).jpg
# Processing image: ../dataset/train\Heart\Heart(672).jpg
# Processing image: ../dataset/train\Heart\Heart(673).jpg
# Processing image: ../dataset/train\Heart\Heart(674).jpg
# Processing image: ../dataset/train\Heart\Heart(675).jpg
# Processing image: ../dataset/train\Heart\Heart(676).jpg
# Processing image: ../dataset/train\Heart\Heart(677).jpg
# Processing image: ../dataset/train\Heart\Heart(678).jpg
# Processing image: ../dataset/train\Heart\Heart(679).jpg
# Processing image: ../dataset/train\Heart\Heart(68).jpg
# Processing image: ../dataset/train\Heart\Heart(680).jpg
# Processing image: ../dataset/train\Heart\Heart(681).jpg
# Processing image: ../dataset/train\Heart\Heart(682).jpg
# Processing image: ../dataset/train\Heart\Heart(683).jpg
# Processing image: ../dataset/train\Heart\Heart(684).jpg
# Processing image: ../dataset/train\Heart\Heart(685).jpg
# Processing image: ../dataset/train\Heart\Heart(686).jpg
# Processing image: ../dataset/train\Heart\Heart(687).jpg
# Processing image: ../dataset/train\Heart\Heart(688).jpg
# Processing image: ../dataset/train\Heart\Heart(689).jpg
# Processing image: ../dataset/train\Heart\Heart(69).jpg
# Processing image: ../dataset/train\Heart\Heart(690).jpg
# Processing image: ../dataset/train\Heart\Heart(691).jpg
# Processing image: ../dataset/train\Heart\Heart(692).jpg
# Processing image: ../dataset/train\Heart\Heart(693).jpg
# Processing image: ../dataset/train\Heart\Heart(694).jpg
# Processing image: ../dataset/train\Heart\Heart(695).jpg
# Processing image: ../dataset/train\Heart\Heart(696).jpg
# Processing image: ../dataset/train\Heart\Heart(697).jpg
# Processing image: ../dataset/train\Heart\Heart(698).jpg
# Processing image: ../dataset/train\Heart\Heart(699).jpg
# Processing image: ../dataset/train\Heart\Heart(7).jpg
# Processing image: ../dataset/train\Heart\Heart(70).jpg
# Processing image: ../dataset/train\Heart\Heart(700).jpg
# Processing image: ../dataset/train\Heart\Heart(701).jpg
# Processing image: ../dataset/train\Heart\Heart(702).jpg
# Processing image: ../dataset/train\Heart\Heart(703).jpg
# Processing image: ../dataset/train\Heart\Heart(704).jpg
# Processing image: ../dataset/train\Heart\Heart(705).jpg
# Processing image: ../dataset/train\Heart\Heart(706).jpg
# Processing image: ../dataset/train\Heart\Heart(707).jpg
# Processing image: ../dataset/train\Heart\Heart(708).jpg
# Processing image: ../dataset/train\Heart\Heart(709).jpg
# Processing image: ../dataset/train\Heart\Heart(71).jpg
# Processing image: ../dataset/train\Heart\Heart(710).jpg
# Processing image: ../dataset/train\Heart\Heart(711).jpg
# Processing image: ../dataset/train\Heart\Heart(712).jpg
# Processing image: ../dataset/train\Heart\Heart(713).jpg
# Processing image: ../dataset/train\Heart\Heart(714).jpg
# Processing image: ../dataset/train\Heart\Heart(715).jpg
# Processing image: ../dataset/train\Heart\Heart(716).jpg
# Processing image: ../dataset/train\Heart\Heart(717).jpg
# Processing image: ../dataset/train\Heart\Heart(718).jpg
# Processing image: ../dataset/train\Heart\Heart(719).jpg
# Processing image: ../dataset/train\Heart\Heart(72).jpg
# Processing image: ../dataset/train\Heart\Heart(720).jpg
# Processing image: ../dataset/train\Heart\Heart(721).jpg
# Processing image: ../dataset/train\Heart\Heart(722).jpg
# Processing image: ../dataset/train\Heart\Heart(723).jpg
# Processing image: ../dataset/train\Heart\Heart(724).jpg
# Processing image: ../dataset/train\Heart\Heart(725).jpg
# Processing image: ../dataset/train\Heart\Heart(726).jpg
# Processing image: ../dataset/train\Heart\Heart(727).jpg
# Processing image: ../dataset/train\Heart\Heart(728).jpg
# Processing image: ../dataset/train\Heart\Heart(729).jpg
# Processing image: ../dataset/train\Heart\Heart(73).jpg
# Processing image: ../dataset/train\Heart\Heart(730).jpg
# Processing image: ../dataset/train\Heart\Heart(731).jpg
# Processing image: ../dataset/train\Heart\Heart(732).jpg
# Processing image: ../dataset/train\Heart\Heart(733).jpg
# Processing image: ../dataset/train\Heart\Heart(734).jpg
# Processing image: ../dataset/train\Heart\Heart(735).jpg
# Processing image: ../dataset/train\Heart\Heart(736).jpg
# Processing image: ../dataset/train\Heart\Heart(737).jpg
# Processing image: ../dataset/train\Heart\Heart(738).jpg
# Processing image: ../dataset/train\Heart\Heart(739).jpg
# Processing image: ../dataset/train\Heart\Heart(74).jpg
# Processing image: ../dataset/train\Heart\Heart(740).jpg
# Processing image: ../dataset/train\Heart\Heart(741).jpg
# Processing image: ../dataset/train\Heart\Heart(742).jpg
# Processing image: ../dataset/train\Heart\Heart(743).jpg
# Processing image: ../dataset/train\Heart\Heart(744).jpg
# Processing image: ../dataset/train\Heart\Heart(745).jpg
# Processing image: ../dataset/train\Heart\Heart(746).jpg
# Processing image: ../dataset/train\Heart\Heart(747).jpg
# Processing image: ../dataset/train\Heart\Heart(748).jpg
# Processing image: ../dataset/train\Heart\Heart(749).jpg
# Processing image: ../dataset/train\Heart\Heart(75).jpg
# Processing image: ../dataset/train\Heart\Heart(750).jpg
# Processing image: ../dataset/train\Heart\Heart(751).jpg
# Processing image: ../dataset/train\Heart\Heart(752).jpg
# Processing image: ../dataset/train\Heart\Heart(753).jpg
# Processing image: ../dataset/train\Heart\Heart(754).jpg
# Processing image: ../dataset/train\Heart\Heart(755).jpg
# Processing image: ../dataset/train\Heart\Heart(756).jpg
# Processing image: ../dataset/train\Heart\Heart(757).jpg
# Processing image: ../dataset/train\Heart\Heart(758).jpg
# Processing image: ../dataset/train\Heart\Heart(759).jpg
# Processing image: ../dataset/train\Heart\Heart(76).jpg
# Processing image: ../dataset/train\Heart\Heart(760).jpg
# Processing image: ../dataset/train\Heart\Heart(761).jpg
# Processing image: ../dataset/train\Heart\Heart(762).jpg
# Processing image: ../dataset/train\Heart\Heart(763).jpg
# Processing image: ../dataset/train\Heart\Heart(764).jpg
# Processing image: ../dataset/train\Heart\Heart(765).jpg
# Processing image: ../dataset/train\Heart\Heart(766).jpg
# Processing image: ../dataset/train\Heart\Heart(767).jpg
# Processing image: ../dataset/train\Heart\Heart(768).jpg
# Processing image: ../dataset/train\Heart\Heart(769).jpg
# Processing image: ../dataset/train\Heart\Heart(77).jpg
# Processing image: ../dataset/train\Heart\Heart(770).jpg
# Processing image: ../dataset/train\Heart\Heart(771).jpg
# Processing image: ../dataset/train\Heart\Heart(772).jpg
# Processing image: ../dataset/train\Heart\Heart(773).jpg
# Processing image: ../dataset/train\Heart\Heart(774).jpg
# Processing image: ../dataset/train\Heart\Heart(775).jpg
# Processing image: ../dataset/train\Heart\Heart(776).jpg
# Processing image: ../dataset/train\Heart\Heart(777).jpg
# Processing image: ../dataset/train\Heart\Heart(778).jpg
# Processing image: ../dataset/train\Heart\Heart(779).jpg
# Processing image: ../dataset/train\Heart\Heart(78).jpg
# Processing image: ../dataset/train\Heart\Heart(780).jpg
# Processing image: ../dataset/train\Heart\Heart(781).jpg
# Processing image: ../dataset/train\Heart\Heart(782).jpg
# Processing image: ../dataset/train\Heart\Heart(783).jpg
# Processing image: ../dataset/train\Heart\Heart(784).jpg
# Processing image: ../dataset/train\Heart\Heart(785).jpg
# Processing image: ../dataset/train\Heart\Heart(786).jpg
# Processing image: ../dataset/train\Heart\Heart(787).jpg
# Processing image: ../dataset/train\Heart\Heart(788).jpg
# Processing image: ../dataset/train\Heart\Heart(789).jpg
# Processing image: ../dataset/train\Heart\Heart(79).jpg
# Processing image: ../dataset/train\Heart\Heart(790).jpg
# Processing image: ../dataset/train\Heart\Heart(791).jpg
# Processing image: ../dataset/train\Heart\Heart(792).jpg
# Processing image: ../dataset/train\Heart\Heart(793).jpg
# Processing image: ../dataset/train\Heart\Heart(794).jpg
# Processing image: ../dataset/train\Heart\Heart(795).jpg
# Processing image: ../dataset/train\Heart\Heart(796).jpg
# Processing image: ../dataset/train\Heart\Heart(797).jpg
# Processing image: ../dataset/train\Heart\Heart(8).jpg
# Processing image: ../dataset/train\Heart\Heart(80).jpg
# Processing image: ../dataset/train\Heart\Heart(81).jpg
# Processing image: ../dataset/train\Heart\Heart(82).jpg
# Processing image: ../dataset/train\Heart\Heart(83).jpg
# Processing image: ../dataset/train\Heart\Heart(84).jpg
# Processing image: ../dataset/train\Heart\Heart(85).jpg
# Processing image: ../dataset/train\Heart\Heart(86).jpg
# Processing image: ../dataset/train\Heart\Heart(87).jpg
# Processing image: ../dataset/train\Heart\Heart(88).jpg
# Processing image: ../dataset/train\Heart\Heart(89).jpg
# Processing image: ../dataset/train\Heart\Heart(9).jpg
# Processing image: ../dataset/train\Heart\Heart(90).jpg
# Processing image: ../dataset/train\Heart\Heart(91).jpg
# Processing image: ../dataset/train\Heart\Heart(92).jpg
# Processing image: ../dataset/train\Heart\Heart(93).jpg
# Processing image: ../dataset/train\Heart\Heart(94).jpg
# Processing image: ../dataset/train\Heart\Heart(95).jpg
# Processing image: ../dataset/train\Heart\Heart(96).jpg
# Processing image: ../dataset/train\Heart\Heart(97).jpg
# Processing image: ../dataset/train\Heart\Heart(98).jpg
# Processing image: ../dataset/train\Heart\Heart(99).jpg
# Processing image: ../dataset/train\Oblong\Oblong(0).jpg
# Processing image: ../dataset/train\Oblong\Oblong(1).jpg
# Processing image: ../dataset/train\Oblong\Oblong(10).jpg
# Processing image: ../dataset/train\Oblong\Oblong(100).jpg
# Processing image: ../dataset/train\Oblong\Oblong(101).jpg
# Processing image: ../dataset/train\Oblong\Oblong(102).jpg
# Processing image: ../dataset/train\Oblong\Oblong(103).jpg
# Processing image: ../dataset/train\Oblong\Oblong(104).jpg
# Processing image: ../dataset/train\Oblong\Oblong(105).jpg
# Processing image: ../dataset/train\Oblong\Oblong(106).jpg
# Processing image: ../dataset/train\Oblong\Oblong(107).jpg
# Processing image: ../dataset/train\Oblong\Oblong(108).jpg
# Processing image: ../dataset/train\Oblong\Oblong(109).jpg
# Processing image: ../dataset/train\Oblong\Oblong(11).jpg
# Processing image: ../dataset/train\Oblong\Oblong(110).jpg
# Processing image: ../dataset/train\Oblong\Oblong(111).jpg
# Processing image: ../dataset/train\Oblong\Oblong(112).jpg
# Processing image: ../dataset/train\Oblong\Oblong(113).jpg
# Processing image: ../dataset/train\Oblong\Oblong(114).jpg
# Processing image: ../dataset/train\Oblong\Oblong(115).jpg
# Processing image: ../dataset/train\Oblong\Oblong(116).jpg
# Processing image: ../dataset/train\Oblong\Oblong(117).jpg
# Processing image: ../dataset/train\Oblong\Oblong(118).jpg
# Processing image: ../dataset/train\Oblong\Oblong(119).jpg
# Processing image: ../dataset/train\Oblong\Oblong(12).jpg
# Processing image: ../dataset/train\Oblong\Oblong(120).jpg
# Processing image: ../dataset/train\Oblong\Oblong(121).jpg
# Processing image: ../dataset/train\Oblong\Oblong(122).jpg
# Processing image: ../dataset/train\Oblong\Oblong(123).jpg
# Processing image: ../dataset/train\Oblong\Oblong(124).jpg
# Processing image: ../dataset/train\Oblong\Oblong(125).jpg
# Processing image: ../dataset/train\Oblong\Oblong(126).jpg
# Processing image: ../dataset/train\Oblong\Oblong(127).jpg
# Processing image: ../dataset/train\Oblong\Oblong(128).jpg
# Processing image: ../dataset/train\Oblong\Oblong(129).jpg
# Processing image: ../dataset/train\Oblong\Oblong(13).jpg
# Processing image: ../dataset/train\Oblong\Oblong(130).jpg
# Processing image: ../dataset/train\Oblong\Oblong(131).jpg
# Processing image: ../dataset/train\Oblong\Oblong(132).jpg
# Processing image: ../dataset/train\Oblong\Oblong(133).jpg
# Processing image: ../dataset/train\Oblong\Oblong(134).jpg
# Processing image: ../dataset/train\Oblong\Oblong(135).jpg
# Processing image: ../dataset/train\Oblong\Oblong(136).jpg
# Processing image: ../dataset/train\Oblong\Oblong(137).jpg
# Processing image: ../dataset/train\Oblong\Oblong(138).jpg
# Processing image: ../dataset/train\Oblong\Oblong(139).jpg
# Processing image: ../dataset/train\Oblong\Oblong(14).jpg
# Processing image: ../dataset/train\Oblong\Oblong(140).jpg
# Processing image: ../dataset/train\Oblong\Oblong(141).jpg
# Processing image: ../dataset/train\Oblong\Oblong(142).jpg
# Processing image: ../dataset/train\Oblong\Oblong(143).jpg
# Processing image: ../dataset/train\Oblong\Oblong(144).jpg
# Processing image: ../dataset/train\Oblong\Oblong(145).jpg
# Processing image: ../dataset/train\Oblong\Oblong(146).jpg
# Processing image: ../dataset/train\Oblong\Oblong(147).jpg
# Processing image: ../dataset/train\Oblong\Oblong(148).jpg
# Processing image: ../dataset/train\Oblong\Oblong(149).jpg
# Processing image: ../dataset/train\Oblong\Oblong(15).jpg
# Processing image: ../dataset/train\Oblong\Oblong(150).jpg
# ...
# Processing image: ../dataset/test\Round\Round(20).jpg
# Processing image: ../dataset/test\Round\Round(21).jpg
# Processing image: ../dataset/test\Round\Round(22).jpg
# Processing image: ../dataset/test\Round\Round(23).jpg
# Processing image: ../dataset/test\Round\Round(24).jpg
# Processing image: ../dataset/test\Round\Round(25).jpg
# Processing image: ../dataset/test\Round\Round(26).jpg
# Processing image: ../dataset/test\Round\Round(27).jpg
# Processing image: ../dataset/test\Round\Round(28).jpg
# Processing image: ../dataset/test\Round\Round(29).jpg
# Processing image: ../dataset/test\Round\Round(3).jpg
# Processing image: ../dataset/test\Round\Round(30).jpg
# Processing image: ../dataset/test\Round\Round(31).jpg
# Processing image: ../dataset/test\Round\Round(32).jpg
# Processing image: ../dataset/test\Round\Round(33).jpg
# Processing image: ../dataset/test\Round\Round(34).jpg
# Processing image: ../dataset/test\Round\Round(35).jpg
# Processing image: ../dataset/test\Round\Round(36).jpg
# Processing image: ../dataset/test\Round\Round(37).jpg
# Processing image: ../dataset/test\Round\Round(38).jpg
# Processing image: ../dataset/test\Round\Round(39).jpg
# Processing image: ../dataset/test\Round\Round(4).jpg
# Processing image: ../dataset/test\Round\Round(40).jpg
# Processing image: ../dataset/test\Round\Round(41).jpg
# Processing image: ../dataset/test\Round\Round(42).jpg
# Processing image: ../dataset/test\Round\Round(43).jpg
# Processing image: ../dataset/test\Round\Round(44).jpg
# Processing image: ../dataset/test\Round\Round(45).jpg
# Processing image: ../dataset/test\Round\Round(46).jpg
# Processing image: ../dataset/test\Round\Round(47).jpg
# Processing image: ../dataset/test\Round\Round(48).jpg
# Processing image: ../dataset/test\Round\Round(49).jpg
# Processing image: ../dataset/test\Round\Round(5).jpg
# Processing image: ../dataset/test\Round\Round(50).jpg
# Processing image: ../dataset/test\Round\Round(51).jpg
# Processing image: ../dataset/test\Round\Round(52).jpg
# Processing image: ../dataset/test\Round\Round(53).jpg
# Processing image: ../dataset/test\Round\Round(54).jpg
# Processing image: ../dataset/test\Round\Round(55).jpg
# Processing image: ../dataset/test\Round\Round(56).jpg
# Processing image: ../dataset/test\Round\Round(57).jpg
# Processing image: ../dataset/test\Round\Round(58).jpg
# Processing image: ../dataset/test\Round\Round(59).jpg
# Processing image: ../dataset/test\Round\Round(6).jpg
# Processing image: ../dataset/test\Round\Round(60).jpg
# Processing image: ../dataset/test\Round\Round(61).jpg
# Processing image: ../dataset/test\Round\Round(62).jpg
# Processing image: ../dataset/test\Round\Round(63).jpg
# Processing image: ../dataset/test\Round\Round(64).jpg
# Processing image: ../dataset/test\Round\Round(65).jpg
# Processing image: ../dataset/test\Round\Round(66).jpg
# Processing image: ../dataset/test\Round\Round(67).jpg
# Processing image: ../dataset/test\Round\Round(68).jpg
# Processing image: ../dataset/test\Round\Round(69).jpg
# Processing image: ../dataset/test\Round\Round(7).jpg
# Processing image: ../dataset/test\Round\Round(70).jpg
# Processing image: ../dataset/test\Round\Round(71).jpg
# Processing image: ../dataset/test\Round\Round(72).jpg
# Processing image: ../dataset/test\Round\Round(73).jpg
# Processing image: ../dataset/test\Round\Round(74).jpg
# Processing image: ../dataset/test\Round\Round(75).jpg
# Processing image: ../dataset/test\Round\Round(76).jpg
# Processing image: ../dataset/test\Round\Round(77).jpg
# Processing image: ../dataset/test\Round\Round(78).jpg
# Processing image: ../dataset/test\Round\Round(79).jpg
# Processing image: ../dataset/test\Round\Round(8).jpg
# Processing image: ../dataset/test\Round\Round(80).jpg
# Processing image: ../dataset/test\Round\Round(81).jpg
# Processing image: ../dataset/test\Round\Round(82).jpg
# Processing image: ../dataset/test\Round\Round(83).jpg
# Processing image: ../dataset/test\Round\Round(84).jpg
# Processing image: ../dataset/test\Round\Round(85).jpg
# Processing image: ../dataset/test\Round\Round(86).jpg
# Processing image: ../dataset/test\Round\Round(87).jpg
# Processing image: ../dataset/test\Round\Round(88).jpg
# Processing image: ../dataset/test\Round\Round(89).jpg
# Processing image: ../dataset/test\Round\Round(9).jpg
# Processing image: ../dataset/test\Round\Round(90).jpg
# Processing image: ../dataset/test\Round\Round(91).jpg
# Processing image: ../dataset/test\Round\Round(92).jpg
# Processing image: ../dataset/test\Round\Round(93).jpg
# Processing image: ../dataset/test\Round\Round(94).jpg
# Processing image: ../dataset/test\Round\Round(95).jpg
# Processing image: ../dataset/test\Round\Round(96).jpg
# Processing image: ../dataset/test\Round\Round(97).jpg
# Processing image: ../dataset/test\Round\Round(98).jpg
# Processing image: ../dataset/test\Round\Round(99).jpg
# Processing image: ../dataset/test\Square\Square(0).jpg
# Processing image: ../dataset/test\Square\Square(1).jpg
# Processing image: ../dataset/test\Square\Square(10).jpg
# Processing image: ../dataset/test\Square\Square(100).jpg
# Processing image: ../dataset/test\Square\Square(101).jpg
# Processing image: ../dataset/test\Square\Square(102).jpg
# Processing image: ../dataset/test\Square\Square(103).jpg
# Processing image: ../dataset/test\Square\Square(104).jpg
# Processing image: ../dataset/test\Square\Square(105).jpg
# Processing image: ../dataset/test\Square\Square(106).jpg
# Processing image: ../dataset/test\Square\Square(107).jpg
# Processing image: ../dataset/test\Square\Square(108).jpg
# Processing image: ../dataset/test\Square\Square(109).jpg
# Processing image: ../dataset/test\Square\Square(11).jpg
# Processing image: ../dataset/test\Square\Square(110).jpg
# Processing image: ../dataset/test\Square\Square(111).jpg
# Processing image: ../dataset/test\Square\Square(112).jpg
# Processing image: ../dataset/test\Square\Square(113).jpg
# Processing image: ../dataset/test\Square\Square(114).jpg
# Processing image: ../dataset/test\Square\Square(115).jpg
# Processing image: ../dataset/test\Square\Square(116).jpg
# Processing image: ../dataset/test\Square\Square(117).jpg
# Processing image: ../dataset/test\Square\Square(118).jpg
# Processing image: ../dataset/test\Square\Square(119).jpg
# Processing image: ../dataset/test\Square\Square(12).jpg
# Processing image: ../dataset/test\Square\Square(120).jpg
# Processing image: ../dataset/test\Square\Square(121).jpg
# Processing image: ../dataset/test\Square\Square(122).jpg
# Processing image: ../dataset/test\Square\Square(123).jpg
# Processing image: ../dataset/test\Square\Square(124).jpg
# Processing image: ../dataset/test\Square\Square(125).jpg
# Processing image: ../dataset/test\Square\Square(126).jpg
# Processing image: ../dataset/test\Square\Square(127).jpg
# Processing image: ../dataset/test\Square\Square(128).jpg
# Processing image: ../dataset/test\Square\Square(129).jpg
# Processing image: ../dataset/test\Square\Square(13).jpg
# Processing image: ../dataset/test\Square\Square(130).jpg
# Processing image: ../dataset/test\Square\Square(131).jpg
# Processing image: ../dataset/test\Square\Square(132).jpg
# Processing image: ../dataset/test\Square\Square(133).jpg
# Processing image: ../dataset/test\Square\Square(134).jpg
# Processing image: ../dataset/test\Square\Square(135).jpg
# Processing image: ../dataset/test\Square\Square(136).jpg
# Processing image: ../dataset/test\Square\Square(137).jpg
# Processing image: ../dataset/test\Square\Square(138).jpg
# Processing image: ../dataset/test\Square\Square(139).jpg
# Processing image: ../dataset/test\Square\Square(14).jpg
# Processing image: ../dataset/test\Square\Square(140).jpg
# Processing image: ../dataset/test\Square\Square(141).jpg
# Processing image: ../dataset/test\Square\Square(142).jpg
# Processing image: ../dataset/test\Square\Square(143).jpg
# Processing image: ../dataset/test\Square\Square(144).jpg
# Processing image: ../dataset/test\Square\Square(145).jpg
# Processing image: ../dataset/test\Square\Square(146).jpg
# Processing image: ../dataset/test\Square\Square(147).jpg
# Processing image: ../dataset/test\Square\Square(148).jpg
# Processing image: ../dataset/test\Square\Square(149).jpg
# Processing image: ../dataset/test\Square\Square(15).jpg
# Processing image: ../dataset/test\Square\Square(150).jpg
# Processing image: ../dataset/test\Square\Square(151).jpg
# Processing image: ../dataset/test\Square\Square(152).jpg
# Processing image: ../dataset/test\Square\Square(153).jpg
# Processing image: ../dataset/test\Square\Square(154).jpg
# Processing image: ../dataset/test\Square\Square(155).jpg
# Processing image: ../dataset/test\Square\Square(156).jpg
# Processing image: ../dataset/test\Square\Square(157).jpg
# Processing image: ../dataset/test\Square\Square(158).jpg
# Processing image: ../dataset/test\Square\Square(159).jpg
# Processing image: ../dataset/test\Square\Square(16).jpg
# Processing image: ../dataset/test\Square\Square(160).jpg
# Processing image: ../dataset/test\Square\Square(161).jpg
# Processing image: ../dataset/test\Square\Square(162).jpg
# Processing image: ../dataset/test\Square\Square(163).jpg
# Processing image: ../dataset/test\Square\Square(164).jpg
# Processing image: ../dataset/test\Square\Square(165).jpg
# Processing image: ../dataset/test\Square\Square(166).jpg
# Processing image: ../dataset/test\Square\Square(167).jpg
# Processing image: ../dataset/test\Square\Square(168).jpg
# Processing image: ../dataset/test\Square\Square(169).jpg
# Processing image: ../dataset/test\Square\Square(17).jpg
# Processing image: ../dataset/test\Square\Square(170).jpg
# Processing image: ../dataset/test\Square\Square(171).jpg
# Processing image: ../dataset/test\Square\Square(172).jpg
# Processing image: ../dataset/test\Square\Square(173).jpg
# Processing image: ../dataset/test\Square\Square(174).jpg
# Processing image: ../dataset/test\Square\Square(175).jpg
# Processing image: ../dataset/test\Square\Square(176).jpg
# Processing image: ../dataset/test\Square\Square(177).jpg
# Processing image: ../dataset/test\Square\Square(178).jpg
# Processing image: ../dataset/test\Square\Square(179).jpg
# Processing image: ../dataset/test\Square\Square(18).jpg
# Processing image: ../dataset/test\Square\Square(180).jpg
# Processing image: ../dataset/test\Square\Square(181).jpg
# Processing image: ../dataset/test\Square\Square(182).jpg
# Processing image: ../dataset/test\Square\Square(183).jpg
# Processing image: ../dataset/test\Square\Square(184).jpg
# Processing image: ../dataset/test\Square\Square(185).jpg
# Processing image: ../dataset/test\Square\Square(186).jpg
# Processing image: ../dataset/test\Square\Square(187).jpg
# Processing image: ../dataset/test\Square\Square(188).jpg
# Processing image: ../dataset/test\Square\Square(189).jpg
# Processing image: ../dataset/test\Square\Square(19).jpg
# Processing image: ../dataset/test\Square\Square(190).jpg
# Processing image: ../dataset/test\Square\Square(191).jpg
# Processing image: ../dataset/test\Square\Square(192).jpg
# Processing image: ../dataset/test\Square\Square(193).jpg
# Processing image: ../dataset/test\Square\Square(194).jpg
# Processing image: ../dataset/test\Square\Square(195).jpg
# Processing image: ../dataset/test\Square\Square(196).jpg
# Processing image: ../dataset/test\Square\Square(197).jpg
# Processing image: ../dataset/test\Square\Square(198).jpg
# Processing image: ../dataset/test\Square\Square(199).jpg
# Processing image: ../dataset/test\Square\Square(2).jpg
# Processing image: ../dataset/test\Square\Square(20).jpg
# Processing image: ../dataset/test\Square\Square(21).jpg
# Processing image: ../dataset/test\Square\Square(22).jpg
# Processing image: ../dataset/test\Square\Square(23).jpg
# Processing image: ../dataset/test\Square\Square(24).jpg
# Processing image: ../dataset/test\Square\Square(25).jpg
# Processing image: ../dataset/test\Square\Square(26).jpg
# Processing image: ../dataset/test\Square\Square(27).jpg
# Processing image: ../dataset/test\Square\Square(28).jpg
# Processing image: ../dataset/test\Square\Square(29).jpg
# Processing image: ../dataset/test\Square\Square(3).jpg
# Processing image: ../dataset/test\Square\Square(30).jpg
# Processing image: ../dataset/test\Square\Square(31).jpg
# Processing image: ../dataset/test\Square\Square(32).jpg
# Processing image: ../dataset/test\Square\Square(33).jpg
# Processing image: ../dataset/test\Square\Square(34).jpg
# Processing image: ../dataset/test\Square\Square(35).jpg
# Processing image: ../dataset/test\Square\Square(36).jpg
# Processing image: ../dataset/test\Square\Square(37).jpg
# Processing image: ../dataset/test\Square\Square(38).jpg
# Processing image: ../dataset/test\Square\Square(39).jpg
# Processing image: ../dataset/test\Square\Square(4).jpg
# Processing image: ../dataset/test\Square\Square(40).jpg
# Processing image: ../dataset/test\Square\Square(41).jpg
# Processing image: ../dataset/test\Square\Square(42).jpg
# Processing image: ../dataset/test\Square\Square(43).jpg
# Processing image: ../dataset/test\Square\Square(44).jpg
# Processing image: ../dataset/test\Square\Square(45).jpg
# Processing image: ../dataset/test\Square\Square(46).jpg
# Processing image: ../dataset/test\Square\Square(47).jpg
# Processing image: ../dataset/test\Square\Square(48).jpg
# Processing image: ../dataset/test\Square\Square(49).jpg
# Processing image: ../dataset/test\Square\Square(5).jpg
# Processing image: ../dataset/test\Square\Square(50).jpg
# Processing image: ../dataset/test\Square\Square(51).jpg
# Processing image: ../dataset/test\Square\Square(52).jpg
# Processing image: ../dataset/test\Square\Square(53).jpg
# Processing image: ../dataset/test\Square\Square(54).jpg
# Processing image: ../dataset/test\Square\Square(55).jpg
# Processing image: ../dataset/test\Square\Square(56).jpg
# Processing image: ../dataset/test\Square\Square(57).jpg
# Processing image: ../dataset/test\Square\Square(58).jpg
# Processing image: ../dataset/test\Square\Square(59).jpg
# Processing image: ../dataset/test\Square\Square(6).jpg
# Processing image: ../dataset/test\Square\Square(60).jpg
# Processing image: ../dataset/test\Square\Square(61).jpg
# Processing image: ../dataset/test\Square\Square(62).jpg
# Processing image: ../dataset/test\Square\Square(63).jpg
# Processing image: ../dataset/test\Square\Square(64).jpg
# Processing image: ../dataset/test\Square\Square(65).jpg
# Processing image: ../dataset/test\Square\Square(66).jpg
# Processing image: ../dataset/test\Square\Square(67).jpg
# Processing image: ../dataset/test\Square\Square(68).jpg
# Processing image: ../dataset/test\Square\Square(69).jpg
# Processing image: ../dataset/test\Square\Square(7).jpg
# Processing image: ../dataset/test\Square\Square(70).jpg
# Processing image: ../dataset/test\Square\Square(71).jpg
# Processing image: ../dataset/test\Square\Square(72).jpg
# Processing image: ../dataset/test\Square\Square(73).jpg
# Processing image: ../dataset/test\Square\Square(74).jpg
# Processing image: ../dataset/test\Square\Square(75).jpg
# Processing image: ../dataset/test\Square\Square(76).jpg
# Processing image: ../dataset/test\Square\Square(77).jpg
# Processing image: ../dataset/test\Square\Square(78).jpg
# Processing image: ../dataset/test\Square\Square(79).jpg
# Processing image: ../dataset/test\Square\Square(8).jpg
# Processing image: ../dataset/test\Square\Square(80).jpg
# Processing image: ../dataset/test\Square\Square(81).jpg
# Processing image: ../dataset/test\Square\Square(82).jpg
# Processing image: ../dataset/test\Square\Square(83).jpg
# Processing image: ../dataset/test\Square\Square(84).jpg
# Processing image: ../dataset/test\Square\Square(85).jpg
# Processing image: ../dataset/test\Square\Square(86).jpg
# Processing image: ../dataset/test\Square\Square(87).jpg
# Processing image: ../dataset/test\Square\Square(88).jpg
# Processing image: ../dataset/test\Square\Square(89).jpg
# Processing image: ../dataset/test\Square\Square(9).jpg
# Processing image: ../dataset/test\Square\Square(90).jpg
# Processing image: ../dataset/test\Square\Square(91).jpg
# Processing image: ../dataset/test\Square\Square(92).jpg
# Processing image: ../dataset/test\Square\Square(93).jpg
# Processing image: ../dataset/test\Square\Square(94).jpg
# Processing image: ../dataset/test\Square\Square(95).jpg
# Processing image: ../dataset/test\Square\Square(96).jpg
# Processing image: ../dataset/test\Square\Square(97).jpg
# Processing image: ../dataset/test\Square\Square(98).jpg
# Processing image: ../dataset/test\Square\Square(99).jpg

# %%
# Trial 2 finished with value: 0.7867305874824524 and parameters: {'learning_rate': 0.00013285427305222708, 'dense_units': 512, 'dropout_rate': 0.3004578707566693, 'batch_size': 32}. Best is trial 2 with value: 0.7867305874824524


model.compile(
    optimizer=Adam(learning_rate=0.00013285427305222708),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

checkpoint_callback = ModelCheckpoint(
    filepath='vgg16_model_{epoch:02d}.h5',
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)


# early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_test,y_test),
    epochs=90,
    batch_size=16,
    # callbacks=[early_stopping],
    verbose=1
)

test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# Epoch 1/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 539s 2s/step - accuracy: 0.3887 - loss: 1.4433 - val_accuracy: 0.5053 - val_loss: 1.2598
# Epoch 2/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 525s 2s/step - accuracy: 0.4907 - loss: 1.2319 - val_accuracy: 0.4727 - val_loss: 1.2572
# Epoch 3/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.5411 - loss: 1.1316 - val_accuracy: 0.5315 - val_loss: 1.1598
# Epoch 4/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 487s 2s/step - accuracy: 0.5896 - loss: 1.0364 - val_accuracy: 0.5588 - val_loss: 1.1015
# Epoch 5/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.6196 - loss: 0.9464 - val_accuracy: 0.5882 - val_loss: 1.0406
# Epoch 6/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 809s 3s/step - accuracy: 0.6797 - loss: 0.8608 - val_accuracy: 0.6019 - val_loss: 1.0248
# Epoch 7/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 812s 3s/step - accuracy: 0.6885 - loss: 0.8295 - val_accuracy: 0.6103 - val_loss: 0.9986
# Epoch 8/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 887s 4s/step - accuracy: 0.7206 - loss: 0.7663 - val_accuracy: 0.6197 - val_loss: 0.9878
# Epoch 9/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 898s 4s/step - accuracy: 0.7485 - loss: 0.7155 - val_accuracy: 0.6313 - val_loss: 0.9731
# Epoch 10/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 870s 3s/step - accuracy: 0.7727 - loss: 0.6572 - val_accuracy: 0.6607 - val_loss: 0.9496
# Epoch 11/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 831s 3s/step - accuracy: 0.7845 - loss: 0.6209 - val_accuracy: 0.6565 - val_loss: 0.9312
# Epoch 12/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 814s 3s/step - accuracy: 0.8027 - loss: 0.5793 - val_accuracy: 0.6492 - val_loss: 0.9249
# Epoch 13/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 839s 4s/step - accuracy: 0.8219 - loss: 0.5257 - val_accuracy: 0.6544 - val_loss: 0.9208
# Epoch 14/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 435s 2s/step - accuracy: 0.8240 - loss: 0.5140 - val_accuracy: 0.6450 - val_loss: 0.9430
# Epoch 15/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 522s 2s/step - accuracy: 0.8438 - loss: 0.4884 - val_accuracy: 0.6471 - val_loss: 0.9342
# Epoch 16/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 420s 2s/step - accuracy: 0.8596 - loss: 0.4436 - val_accuracy: 0.6649 - val_loss: 0.9145
# Epoch 17/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 452s 2s/step - accuracy: 0.8843 - loss: 0.4070 - val_accuracy: 0.6639 - val_loss: 0.9058
# Epoch 18/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.8760 - loss: 0.3996 - val_accuracy: 0.6576 - val_loss: 0.9018
# Epoch 19/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 635s 2s/step - accuracy: 0.8898 - loss: 0.3588 - val_accuracy: 0.6849 - val_loss: 0.8849
# Epoch 20/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 721s 3s/step - accuracy: 0.8990 - loss: 0.3316 - val_accuracy: 0.6880 - val_loss: 0.9031
# Epoch 21/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 434s 2s/step - accuracy: 0.9083 - loss: 0.3114 - val_accuracy: 0.6681 - val_loss: 0.9259
# Epoch 22/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.9029 - loss: 0.3064 - val_accuracy: 0.6807 - val_loss: 0.9209
# Epoch 23/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.9135 - loss: 0.2802 - val_accuracy: 0.6912 - val_loss: 0.9227
# Epoch 24/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 442s 2s/step - accuracy: 0.9268 - loss: 0.2615 - val_accuracy: 0.6901 - val_loss: 0.9043
# Epoch 25/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 437s 2s/step - accuracy: 0.9348 - loss: 0.2412 - val_accuracy: 0.6670 - val_loss: 0.9552
# Epoch 26/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 480s 2s/step - accuracy: 0.9364 - loss: 0.2257 - val_accuracy: 0.6901 - val_loss: 0.9359
# Epoch 27/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 468s 2s/step - accuracy: 0.9385 - loss: 0.2228 - val_accuracy: 0.6786 - val_loss: 0.9594
# Epoch 28/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 490s 2s/step - accuracy: 0.9488 - loss: 0.2019 - val_accuracy: 0.6901 - val_loss: 0.9074
# Epoch 29/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 483s 2s/step - accuracy: 0.9453 - loss: 0.1997 - val_accuracy: 0.6933 - val_loss: 0.9561
# Epoch 30/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 511s 2s/step - accuracy: 0.9608 - loss: 0.1695 - val_accuracy: 0.6912 - val_loss: 0.9676
# Epoch 31/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 416s 2s/step - accuracy: 0.9591 - loss: 0.1557 - val_accuracy: 0.6891 - val_loss: 0.9547
# Epoch 32/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 421s 2s/step - accuracy: 0.9691 - loss: 0.1424 - val_accuracy: 0.6985 - val_loss: 0.9626
# Epoch 33/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 469s 2s/step - accuracy: 0.9684 - loss: 0.1433 - val_accuracy: 0.6954 - val_loss: 0.9751
# Epoch 34/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 487s 2s/step - accuracy: 0.9732 - loss: 0.1250 - val_accuracy: 0.6891 - val_loss: 0.9844
# Epoch 35/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 403s 2s/step - accuracy: 0.9764 - loss: 0.1211 - val_accuracy: 0.7027 - val_loss: 1.0005
# Epoch 36/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 431s 2s/step - accuracy: 0.9761 - loss: 0.1201 - val_accuracy: 0.6870 - val_loss: 1.0152
# Epoch 37/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 517s 2s/step - accuracy: 0.9721 - loss: 0.1137 - val_accuracy: 0.6985 - val_loss: 0.9973
# Epoch 38/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 422s 2s/step - accuracy: 0.9830 - loss: 0.0981 - val_accuracy: 0.6922 - val_loss: 1.0300
# Epoch 39/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 437s 2s/step - accuracy: 0.9792 - loss: 0.0923 - val_accuracy: 0.6943 - val_loss: 1.0479
# Epoch 40/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 451s 2s/step - accuracy: 0.9812 - loss: 0.0903 - val_accuracy: 0.6964 - val_loss: 1.0331
# Epoch 41/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.9865 - loss: 0.0756 - val_accuracy: 0.6996 - val_loss: 1.0739
# Epoch 42/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 516s 2s/step - accuracy: 0.9807 - loss: 0.0828 - val_accuracy: 0.7006 - val_loss: 1.0626
# Epoch 43/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 444s 2s/step - accuracy: 0.9888 - loss: 0.0728 - val_accuracy: 0.6891 - val_loss: 1.1055
# Epoch 44/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.9909 - loss: 0.0671 - val_accuracy: 0.6943 - val_loss: 1.1009
# Epoch 45/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 406s 2s/step - accuracy: 0.9888 - loss: 0.0697 - val_accuracy: 0.6859 - val_loss: 1.1231
# Epoch 46/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 458s 2s/step - accuracy: 0.9850 - loss: 0.0766 - val_accuracy: 0.6849 - val_loss: 1.1343
# Epoch 47/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 474s 2s/step - accuracy: 0.9844 - loss: 0.0722 - val_accuracy: 0.6880 - val_loss: 1.1391
# Epoch 48/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 437s 2s/step - accuracy: 0.9883 - loss: 0.0666 - val_accuracy: 0.6943 - val_loss: 1.1292
# Epoch 49/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 411s 2s/step - accuracy: 0.9855 - loss: 0.0675 - val_accuracy: 0.7038 - val_loss: 1.1368
# Epoch 50/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.9913 - loss: 0.0473 - val_accuracy: 0.6975 - val_loss: 1.1412
# Epoch 51/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.9930 - loss: 0.0461 - val_accuracy: 0.6796 - val_loss: 1.2084
# Epoch 52/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 426s 2s/step - accuracy: 0.9924 - loss: 0.0458 - val_accuracy: 0.7038 - val_loss: 1.1630
# Epoch 53/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 442s 2s/step - accuracy: 0.9833 - loss: 0.0607 - val_accuracy: 0.6975 - val_loss: 1.2416
# Epoch 54/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 478s 2s/step - accuracy: 0.9885 - loss: 0.0528 - val_accuracy: 0.6859 - val_loss: 1.2682
# Epoch 55/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.9878 - loss: 0.0532 - val_accuracy: 0.6828 - val_loss: 1.2057
# Epoch 56/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 438s 2s/step - accuracy: 0.9929 - loss: 0.0416 - val_accuracy: 0.6891 - val_loss: 1.2365
# Epoch 57/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 436s 2s/step - accuracy: 0.9929 - loss: 0.0431 - val_accuracy: 0.6912 - val_loss: 1.2275
# Epoch 58/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 465s 2s/step - accuracy: 0.9890 - loss: 0.0497 - val_accuracy: 0.6891 - val_loss: 1.2290
# Epoch 59/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 517s 2s/step - accuracy: 0.9942 - loss: 0.0400 - val_accuracy: 0.6975 - val_loss: 1.2179
# Epoch 60/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 408s 2s/step - accuracy: 0.9917 - loss: 0.0422 - val_accuracy: 0.7038 - val_loss: 1.2390
# Epoch 61/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 425s 2s/step - accuracy: 0.9907 - loss: 0.0368 - val_accuracy: 0.6765 - val_loss: 1.3554
# Epoch 62/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.9896 - loss: 0.0394 - val_accuracy: 0.6891 - val_loss: 1.3490
# Epoch 63/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 434s 2s/step - accuracy: 0.9843 - loss: 0.0559 - val_accuracy: 0.6880 - val_loss: 1.2116
# Epoch 64/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 404s 2s/step - accuracy: 0.9922 - loss: 0.0377 - val_accuracy: 0.6975 - val_loss: 1.2370
# Epoch 65/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 448s 2s/step - accuracy: 0.9866 - loss: 0.0474 - val_accuracy: 0.6964 - val_loss: 1.2884
# Epoch 66/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 456s 2s/step - accuracy: 0.9948 - loss: 0.0333 - val_accuracy: 0.6586 - val_loss: 1.4463
# Epoch 67/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 426s 2s/step - accuracy: 0.9884 - loss: 0.0490 - val_accuracy: 0.6964 - val_loss: 1.2655
# Epoch 68/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 412s 2s/step - accuracy: 0.9928 - loss: 0.0352 - val_accuracy: 0.6933 - val_loss: 1.3349
# Epoch 69/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.9960 - loss: 0.0249 - val_accuracy: 0.6954 - val_loss: 1.2973
# Epoch 70/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.9969 - loss: 0.0235 - val_accuracy: 0.6996 - val_loss: 1.3474
# Epoch 71/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 488s 2s/step - accuracy: 0.9894 - loss: 0.0403 - val_accuracy: 0.6954 - val_loss: 1.3059
# Epoch 72/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 421s 2s/step - accuracy: 0.9916 - loss: 0.0408 - val_accuracy: 0.6954 - val_loss: 1.2696
# Epoch 73/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 492s 2s/step - accuracy: 0.9924 - loss: 0.0305 - val_accuracy: 0.6985 - val_loss: 1.2970
# Epoch 74/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.9950 - loss: 0.0303 - val_accuracy: 0.7038 - val_loss: 1.3178
# Epoch 75/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 423s 2s/step - accuracy: 0.9941 - loss: 0.0330 - val_accuracy: 0.6922 - val_loss: 1.3228
# Epoch 76/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 506s 2s/step - accuracy: 0.9905 - loss: 0.0321 - val_accuracy: 0.7069 - val_loss: 1.3057
# Epoch 77/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 482s 2s/step - accuracy: 0.9929 - loss: 0.0351 - val_accuracy: 0.6975 - val_loss: 1.3959
# Epoch 78/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 463s 2s/step - accuracy: 0.9972 - loss: 0.0226 - val_accuracy: 0.6933 - val_loss: 1.3514
# Epoch 79/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.9958 - loss: 0.0230 - val_accuracy: 0.6712 - val_loss: 1.4478
# Epoch 80/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 464s 2s/step - accuracy: 0.9907 - loss: 0.0359 - val_accuracy: 0.6880 - val_loss: 1.4725
# Epoch 81/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 537s 2s/step - accuracy: 0.9941 - loss: 0.0254 - val_accuracy: 0.6807 - val_loss: 1.4682
# Epoch 82/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.9960 - loss: 0.0216 - val_accuracy: 0.6891 - val_loss: 1.2746
# Epoch 83/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.9931 - loss: 0.0293 - val_accuracy: 0.6912 - val_loss: 1.4232
# Epoch 84/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 475s 2s/step - accuracy: 0.9900 - loss: 0.0359 - val_accuracy: 0.6744 - val_loss: 1.4401
# Epoch 85/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 530s 2s/step - accuracy: 0.9904 - loss: 0.0372 - val_accuracy: 0.6985 - val_loss: 1.3549
# Epoch 86/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 453s 2s/step - accuracy: 0.9948 - loss: 0.0207 - val_accuracy: 0.7027 - val_loss: 1.3717
# Epoch 87/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.9936 - loss: 0.0233 - val_accuracy: 0.6975 - val_loss: 1.4437
# Epoch 88/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - accuracy: 0.9998 - loss: 0.0120 - val_accuracy: 0.7038 - val_loss: 1.4835
# Epoch 89/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 515s 2s/step - accuracy: 0.9971 - loss: 0.0215 - val_accuracy: 0.6964 - val_loss: 1.4973
# Epoch 90/90
# 239/239 ━━━━━━━━━━━━━━━━━━━━ 432s 2s/step - accuracy: 0.9863 - loss: 0.0420 - val_accuracy: 0.6796 - val_loss: 1.4859
# Test Accuracy: 67.96%

# %%
# Save the model
model.save('../models/face_shape_classifier.h5')
print("Model saved to '../models/face_shape_classifier.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to '../models/face_shape_classifier.h5'

# %%
model.save('../models/face_shape_classifier.keras')
